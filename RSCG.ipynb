# %% [markdown]
# # RSCG method and Chebyshev polynomial method
# We consider the tight-binding model with s-wave superconducting gap.
#
# We solve the Bogoloiubov-de Gennes equations with gap equations self-consistently.

# %%
include("ChevplusRSCG.jl")
using ChevplusRSCG

Hartree = false
nc = 1000 #Number of Chebyshev polynomials that we consider
Nx = 6 #System size
Ny = 6 #System size
aa = 10.0 #Chebyshev renormalize parameter
bb = 0.0
ωc = 10.0 #Cutoff energy
U = -2.0 #Interaction
initialΔ = 0.1 #Initial guess for the superconducting gap
μ = -0.2 #Chemical potential
finite = true

T = 0.05 #We use T only in the case of RSCG
omegamax = 60π #Parameter for RSCG. This is a cutoff on the imaginary Matsubra axis
println("--------------------------------------")
println("RSCG method")
println("--------------------------------------")
full = false #Full diagonalization or not
RSCG = true
itemax = 20
@time mat_Δ1,HF1 = ChevplusRSCG.iteration(nc,Nx,Ny,aa,bb,ωc,U,initialΔ,μ,full,RSCG,finite,T,Hartree,omegamax,itemax)
println("--------------------------------------")
println("Green's function based Full diagonalization ")
println("--------------------------------------")
full = true #Full diagonalization or not
finite == true
itemax = 20
@time mat_Δ2,HF2 = ChevplusRSCG.iteration(nc,Nx,Ny,aa,bb,ωc,U,initialΔ,μ,full,RSCG,finite,T,Hartree,omegamax,itemax)


println("--------------------------------------")
println("Chebyshev method")
println("--------------------------------------")
full = false #Full diagonalization or not
RSCG = false
itemax = 20
@time mat_Δ3,HF3 = ChevplusRSCG.iteration(nc,Nx,Ny,aa,bb,ωc,U,initialΔ,μ,full,RSCG,finite,T,Hartree,omegamax,itemax)
println("--------------------------------------")
println("Full diagonalization")
println("--------------------------------------")
full = true #Full diagonalization or not
finite = false
itemax = 20
@time mat_Δ4,HF4 = ChevplusRSCG.iteration(nc,Nx,Ny,aa,bb,ωc,U,initialΔ,μ,full,RSCG,finite,T,Hartree,omegamax,itemax)

println("--------------------------------------")
println("-----------Summary           ---------")
println("--------------------------------------")
println("Interaction U: ",U)
println("Chemical potential: ",μ)
println("Imaginary axis methods")
println("Cutoff: ",omegamax," i")
println("Temperature: ", T)
println("RSCG: center V,Δ at (Nx/2,Ny/2): ",HF1[div(Nx,2),div(Ny,2)]," ",mat_Δ1[div(Nx,2),div(Ny,2)])
println("Full: center V,Δ at (Nx/2,Ny/2): ",HF2[div(Nx,2),div(Ny,2)]," ", mat_Δ2[div(Nx,2),div(Ny,2)])

println("Real axis methods")
println("Cutoff: ",ωc)
println("Temperature: zero")
println("Chebyshev with nc=",nc,": center V,Δ at (Nx/2,Ny/2): ",HF3[div(Nx,2),div(Ny,2)]," ",mat_Δ3[div(Nx,2),div(Ny,2)])
println("Full: center V,Δ at(Nx/2,Ny/2): ",HF4[div(Nx,2),div(Ny,2)]," ", mat_Δ4[div(Nx,2),div(Ny,2)])
println("--------------------------------------")
println("All done.")
# Out:
# --------------------------------------
# RSCG method
# --------------------------------------
#   0.243685 seconds (7.17 M allocations: 391.136 MiB, 13.24% gc time)
# ite = 1 eps = 0.45576618876809455
# Δ at center (Nx/2,Ny/2): 0.1675104576171833
# Δ at corner (1,1): 0.1675104576171762
#   0.222341 seconds (7.20 M allocations: 392.383 MiB, 11.71% gc time)
# ite = 2 eps = 0.24776366981341238
# Δ at center (Nx/2,Ny/2): 0.2508902362160601
# Δ at corner (1,1): 0.250890236216053
#   0.226433 seconds (7.23 M allocations: 394.126 MiB, 9.51% gc time)
# ite = 3 eps = 0.087343390660859
# Δ at center (Nx/2,Ny/2): 0.3250381239980573
# Δ at corner (1,1): 0.32503812399805554
#   0.223289 seconds (7.26 M allocations: 395.495 MiB, 9.90% gc time)
# ite = 4 eps = 0.022730346848183692
# Δ at center (Nx/2,Ny/2): 0.37404277878188097
# Δ at corner (1,1): 0.3740427787818845
#   0.227960 seconds (7.27 M allocations: 396.370 MiB, 10.25% gc time)
# ite = 5 eps = 0.005243372510676392
# Δ at center (Nx/2,Ny/2): 0.40112764103194287
# Δ at corner (1,1): 0.4011276410319162
#   0.222144 seconds (7.28 M allocations: 396.625 MiB, 9.52% gc time)
# ite = 6 eps = 0.0011641952296791323
# Δ at center (Nx/2,Ny/2): 0.4148142385842224
# Δ at corner (1,1): 0.4148142385842508
#   0.227497 seconds (7.27 M allocations: 396.381 MiB, 10.41% gc time)
# ite = 7 eps = 0.0002552270799340365
# Δ at center (Nx/2,Ny/2): 0.4214412395071676
# Δ at corner (1,1): 0.42144123950715695
#   0.226374 seconds (7.28 M allocations: 396.506 MiB, 9.47% gc time)
# ite = 8 eps = 5.5687538851328925e-5
# Δ at center (Nx/2,Ny/2): 0.4245862061451735
# Δ at corner (1,1): 0.4245862061451753
#   0.219978 seconds (7.28 M allocations: 396.384 MiB, 9.48% gc time)
# ite = 9 eps = 1.2126426584323418e-5
# Δ at center (Nx/2,Ny/2): 0.4260647435013265
# Δ at corner (1,1): 0.42606474350135315
#   0.219690 seconds (7.27 M allocations: 396.323 MiB, 10.07% gc time)
# ite = 10 eps = 2.638346059763555e-6
# Δ at center (Nx/2,Ny/2): 0.4267567998833872
# Δ at corner (1,1): 0.4267567998831865
#   0.223947 seconds (7.28 M allocations: 396.387 MiB, 9.92% gc time)
# ite = 11 eps = 5.73799914590086e-7
# End 0.42708006637434437
#   4.466851 seconds (81.09 M allocations: 4.312 GiB, 6.42% gc time)
# --------------------------------------
# Green's function based Full diagonalization
# --------------------------------------
#   0.259107 seconds (24.40 k allocations: 3.285 MiB)
# ite = 1 eps = 0.45576618876810127
# Δ at center (Nx/2,Ny/2): 0.16751045761718153
# Δ at corner (1,1): 0.16751045761717975
#   0.050126 seconds (299 allocations: 2.200 MiB)
# ite = 2 eps = 0.24776366981343115
# Δ at center (Nx/2,Ny/2): 0.2508902362160583
# Δ at corner (1,1): 0.2508902362160619
#   0.050670 seconds (299 allocations: 2.200 MiB)
# ite = 3 eps = 0.08734339066085091
# Δ at center (Nx/2,Ny/2): 0.32503812399806087
# Δ at corner (1,1): 0.32503812399806264
#   0.058217 seconds (299 allocations: 2.200 MiB)
# ite = 4 eps = 0.022730346848182276
# Δ at center (Nx/2,Ny/2): 0.3740427787818774
# Δ at corner (1,1): 0.3740427787818774
#   0.053955 seconds (299 allocations: 2.200 MiB)
# ite = 5 eps = 0.005243372510676264
# Δ at center (Nx/2,Ny/2): 0.40112764103195
# Δ at corner (1,1): 0.40112764103195
#   0.054935 seconds (299 allocations: 2.200 MiB)
# ite = 6 eps = 0.0011641952296784423
# Δ at center (Nx/2,Ny/2): 0.41481423858420463
# Δ at corner (1,1): 0.4148142385842064
#   0.053931 seconds (299 allocations: 2.200 MiB)
# ite = 7 eps = 0.0002552270799321791
# Δ at center (Nx/2,Ny/2): 0.42144123950718715
# Δ at corner (1,1): 0.4214412395071907
#   0.057637 seconds (299 allocations: 2.200 MiB, 5.90% gc time)
# ite = 8 eps = 5.568753885163511e-5
# Δ at center (Nx/2,Ny/2): 0.42458620614517883
# Δ at corner (1,1): 0.4245862061451806
#   0.051249 seconds (299 allocations: 2.200 MiB)
# ite = 9 eps = 1.2126426584570614e-5
# Δ at center (Nx/2,Ny/2): 0.4260647435013212
# Δ at corner (1,1): 0.42606474350132295
#   0.050692 seconds (299 allocations: 2.200 MiB)
# ite = 10 eps = 2.638346059772646e-6
# Δ at center (Nx/2,Ny/2): 0.42675679988315274
# Δ at corner (1,1): 0.42675679988315274
#   0.051073 seconds (299 allocations: 2.200 MiB)
# ite = 11 eps = 5.737999145769584e-7
# End 0.4270800663744492
#   0.856206 seconds (46.10 k allocations: 26.011 MiB, 0.40% gc time)
# --------------------------------------
# Chebyshev method
# --------------------------------------
#   0.022811 seconds (158 allocations: 359.469 KiB)
# ite = 1 eps = 0.49736571435769683
# Δ at center (Nx/2,Ny/2): 0.17052415999908807
# Δ at corner (1,1): 0.1705241599990881
#   0.022145 seconds (158 allocations: 359.469 KiB)
# ite = 2 eps = 0.22298357307325659
# Δ at center (Nx/2,Ny/2): 0.2510476063285021
# Δ at corner (1,1): 0.2510476063285022
#   0.022313 seconds (158 allocations: 359.469 KiB)
# ite = 3 eps = 0.07581077534234876
# Δ at center (Nx/2,Ny/2): 0.3201704432468523
# Δ at corner (1,1): 0.3201704432468525
#   0.022970 seconds (158 allocations: 359.469 KiB)
# ite = 4 eps = 0.01974017127582697
# Δ at center (Nx/2,Ny/2): 0.365154300824891
# Δ at corner (1,1): 0.365154300824891
#   0.023112 seconds (158 allocations: 359.469 KiB)
# ite = 5 eps = 0.007435372366744903
# Δ at center (Nx/2,Ny/2): 0.3966410468932268
# Δ at corner (1,1): 0.3966410468932265
#   0.023205 seconds (158 allocations: 359.469 KiB)
# ite = 6 eps = 0.0007274245208779288
# Δ at center (Nx/2,Ny/2): 0.40733877668380075
# Δ at corner (1,1): 0.40733877668380086
#   0.022726 seconds (158 allocations: 359.469 KiB)
# ite = 7 eps = 0.00039383294162095167
# Δ at center (Nx/2,Ny/2): 0.4154225062179223
# Δ at corner (1,1): 0.41542250621792276
#   0.022555 seconds (158 allocations: 359.469 KiB)
# ite = 8 eps = 0.0002439085204195122
# Δ at center (Nx/2,Ny/2): 0.4219103966569563
# Δ at corner (1,1): 0.42191039665695623
#   0.023001 seconds (158 allocations: 359.469 KiB)
# ite = 9 eps = 0.00011358256453294197
# Δ at center (Nx/2,Ny/2): 0.4264069118217937
# Δ at corner (1,1): 0.42640691182179324
#   0.022877 seconds (158 allocations: 359.469 KiB)
# ite = 10 eps = 3.363032199111385e-5
# Δ at center (Nx/2,Ny/2): 0.42887971612874476
# Δ at corner (1,1): 0.42887971612874476
#   0.022954 seconds (158 allocations: 359.469 KiB)
# ite = 11 eps = 6.66243978590292e-6
# Δ at center (Nx/2,Ny/2): 0.42998672768673096
# Δ at corner (1,1): 0.4299867276867311
#   0.023067 seconds (158 allocations: 359.469 KiB)
# ite = 12 eps = 1.0369959584634369e-6
# Δ at center (Nx/2,Ny/2): 0.43042459606471073
# Δ at corner (1,1): 0.43042459606471084
#   0.022778 seconds (158 allocations: 359.469 KiB)
# ite = 13 eps = 1.4446997175802876e-7
# End 0.43058819703479173
#   0.354045 seconds (16.00 k allocations: 5.004 MiB)
# --------------------------------------
# Full diagonalization
# --------------------------------------
#   0.014198 seconds (23.40 k allocations: 578.250 KiB)
# ite = 1 eps = 0.4525485083630871
# Δ at center (Nx/2,Ny/2): 0.16727172573697693
# Δ at corner (1,1): 0.16727172573697538
#   0.008617 seconds (23.38 k allocations: 576.766 KiB)
# ite = 2 eps = 0.2431116122660842
# Δ at center (Nx/2,Ny/2): 0.2497473078106768
# Δ at corner (1,1): 0.24974730781067825
#   0.008649 seconds (23.38 k allocations: 576.766 KiB)
# ite = 3 eps = 0.08454136146553266
# Δ at center (Nx/2,Ny/2): 0.32236382810038866
# Δ at corner (1,1): 0.3223638281003879
#   0.009151 seconds (23.38 k allocations: 576.766 KiB)
# ite = 4 eps = 0.022213656501945594
# Δ at center (Nx/2,Ny/2): 0.37040972780645376
# Δ at corner (1,1): 0.37040972780645587
#   0.008323 seconds (23.38 k allocations: 576.766 KiB)
# ite = 5 eps = 0.005233650629665356
# Δ at center (Nx/2,Ny/2): 0.3972066396664507
# Δ at corner (1,1): 0.3972066396664508
#   0.008256 seconds (23.38 k allocations: 576.766 KiB)
# ite = 6 eps = 0.0011902460823770662
# Δ at center (Nx/2,Ny/2): 0.41091024618266453
# Δ at corner (1,1): 0.410910246182666
#   0.008700 seconds (23.38 k allocations: 576.766 KiB)
# ite = 7 eps = 0.00026743369615844
# Δ at center (Nx/2,Ny/2): 0.4176300258603594
# Δ at corner (1,1): 0.417630025860362
#   0.008303 seconds (23.38 k allocations: 576.766 KiB)
# ite = 8 eps = 5.9810779566057905e-5
# Δ at center (Nx/2,Ny/2): 0.4208598691163989
# Δ at corner (1,1): 0.4208598691164016
#   0.009173 seconds (23.38 k allocations: 576.766 KiB)
# ite = 9 eps = 1.3350405455456984e-5
# Δ at center (Nx/2,Ny/2): 0.4223976156034459
# Δ at corner (1,1): 0.42239761560344824
#   0.008563 seconds (23.38 k allocations: 576.766 KiB)
# ite = 10 eps = 2.977363800008948e-6
# Δ at center (Nx/2,Ny/2): 0.42312646434767065
# Δ at corner (1,1): 0.4231264643476726
#   0.008767 seconds (23.38 k allocations: 576.766 KiB)
# ite = 11 eps = 6.637372921527579e-7
# End 0.4234711857903541
#   0.147632 seconds (267.73 k allocations: 6.517 MiB, 2.07% gc time)
# --------------------------------------
# -----------Summary           ---------
# --------------------------------------
# Interaction U: -2.0
# Chemical potential: -0.2
# Imaginary axis methods
# Cutoff: 188.49555921538757 i
# Temperature: 0.05
# RSCG: center V,Δ at (Nx/2,Ny/2): 0.0 0.4267567998833872
# Full: center V,Δ at (Nx/2,Ny/2): 0.0 0.42675679988315274
# Real axis methods
# Cutoff: 10.0
# Temperature: zero
# Chebyshev with nc=1000: center V,Δ at (Nx/2,Ny/2): 0.0 0.43042459606471073
# Full: center V,Δ at(Nx/2,Ny/2): 0.0 0.42312646434767065
# --------------------------------------
# All done.

# %% [markdown]
# Add Hartree term.
#
# We can calculate the Hartree and gap simultaneously.

# %%
include("ChevplusRSCG.jl")
using ChevplusRSCG

Hartree = true
nc = 1000 #Number of Chebyshev polynomials that we consider
Nx = 6 #System size
Ny = 6 #System size
aa = 10.0 #Chebyshev renormalize parameter
bb = 0.0
ωc = 10.0 #Cutoff energy
U = -2.0 #Interaction
initialΔ = 0.1 #Initial guess for the superconducting gap
μ = -0.2 #Chemical potential
finite = true

T = 0.05 #We use T only in the case of RSCG
omegamax = 60π #Parameter for RSCG. This is a cutoff on the imaginary Matsubra axis
println("--------------------------------------")
println("RSCG method")
println("--------------------------------------")
full = false #Full diagonalization or not
RSCG = true
itemax = 20
@time mat_Δ1,HF1 = ChevplusRSCG.iteration(nc,Nx,Ny,aa,bb,ωc,U,initialΔ,μ,full,RSCG,finite,T,Hartree,omegamax,itemax)
println("--------------------------------------")
println("Green's function based Full diagonalization ")
println("--------------------------------------")
full = true #Full diagonalization or not
finite == true
itemax = 20
@time mat_Δ2,HF2 = ChevplusRSCG.iteration(nc,Nx,Ny,aa,bb,ωc,U,initialΔ,μ,full,RSCG,finite,T,Hartree,omegamax,itemax)


println("--------------------------------------")
println("Chebyshev method")
println("--------------------------------------")
full = false #Full diagonalization or not
RSCG = false
itemax = 20
@time mat_Δ3,HF3 = ChevplusRSCG.iteration(nc,Nx,Ny,aa,bb,ωc,U,initialΔ,μ,full,RSCG,finite,T,Hartree,omegamax,itemax)
println("--------------------------------------")
println("Full diagonalization")
println("--------------------------------------")
full = true #Full diagonalization or not
finite = false
itemax = 20
@time mat_Δ4,HF4 = ChevplusRSCG.iteration(nc,Nx,Ny,aa,bb,ωc,U,initialΔ,μ,full,RSCG,finite,T,Hartree,omegamax,itemax)

println("--------------------------------------")
println("-----------Summary           ---------")
println("--------------------------------------")
println("Interaction U: ",U)
println("Chemical potential: ",μ)
println("Imaginary axis methods")
println("Cutoff: ",omegamax," i")
println("Temperature: ", T)
println("RSCG: center V,Δ at (Nx/2,Ny/2): ",HF1[div(Nx,2),div(Ny,2)]," ",mat_Δ1[div(Nx,2),div(Ny,2)])
println("Full: center V,Δ at (Nx/2,Ny/2): ",HF2[div(Nx,2),div(Ny,2)]," ", mat_Δ2[div(Nx,2),div(Ny,2)])

println("Real axis methods")
println("Cutoff: ",ωc)
println("Temperature: zero")
println("Chebyshev with nc=",nc,": center V,Δ at (Nx/2,Ny/2): ",HF3[div(Nx,2),div(Ny,2)]," ",mat_Δ3[div(Nx,2),div(Ny,2)])
println("Full: center V,Δ at(Nx/2,Ny/2): ",HF4[div(Nx,2),div(Ny,2)]," ", mat_Δ4[div(Nx,2),div(Ny,2)])
println("--------------------------------------")
println("All done.")
# Out:
# --------------------------------------
# RSCG method
# --------------------------------------
# WARNING: replacing module chebyshev
# WARNING: replacing module rscg
# WARNING: replacing module ChevplusRSCG
#   0.302695 seconds (7.17 M allocations: 451.477 MiB, 20.34% gc time)
# ite = 1 eps = 0.45576618876809455
# V,Δ at center (Nx/2,Ny/2): -0.7572874834801961 0.1675104576171833
# Δ at corner (1,1): 0.1675104576171762
#   0.277992 seconds (7.20 M allocations: 452.900 MiB, 16.66% gc time)
# ite = 2 eps = 0.24776366981341794
# V,Δ at center (Nx/2,Ny/2): -0.7885201019866634 0.25089023621606366
# Δ at corner (1,1): 0.2508902362160583
#   0.253708 seconds (7.23 M allocations: 454.889 MiB, 15.14% gc time)
# ite = 3 eps = 0.08734339066085775
# V,Δ at center (Nx/2,Ny/2): -0.8248886601295895 0.32503812399806264
# Δ at corner (1,1): 0.3250381239980662
#   0.263996 seconds (7.26 M allocations: 456.451 MiB, 15.57% gc time)
# ite = 4 eps = 0.022730346848182398
# V,Δ at center (Nx/2,Ny/2): -0.8501738616743815 0.37404277878188985
# Δ at corner (1,1): 0.3740427787818934
#   0.262593 seconds (7.27 M allocations: 457.450 MiB, 15.46% gc time)
# ite = 5 eps = 0.005243372510674901
# V,Δ at center (Nx/2,Ny/2): -0.8633238131433181 0.40112764103195886
# Δ at corner (1,1): 0.40112764103196774
#   0.256123 seconds (7.28 M allocations: 457.740 MiB, 15.09% gc time)
# ite = 6 eps = 0.0011641952296792587
# V,Δ at center (Nx/2,Ny/2): -0.8695610880496671 0.4148142385842011
# Δ at corner (1,1): 0.4148142385842277
#   0.257311 seconds (7.28 M allocations: 457.460 MiB, 14.83% gc time)
# ite = 7 eps = 0.00025522707993116413
# V,Δ at center (Nx/2,Ny/2): -0.8724662274591708 0.42144123950726176
# Δ at corner (1,1): 0.42144123950718004
#   0.254504 seconds (7.28 M allocations: 457.603 MiB, 15.09% gc time)
# ite = 8 eps = 5.5687538851732986e-5
# V,Δ at center (Nx/2,Ny/2): -0.8738173289834632 0.4245862061451309
# Δ at corner (1,1): 0.42458620614498166
#   0.251826 seconds (7.28 M allocations: 457.463 MiB, 14.70% gc time)
# ite = 9 eps = 1.2126426584652128e-5
# V,Δ at center (Nx/2,Ny/2): -0.8744462678595035 0.4260647435012874
# Δ at corner (1,1): 0.42606474350131585
#   0.264450 seconds (7.27 M allocations: 457.393 MiB, 15.94% gc time)
# ite = 10 eps = 2.6383460598039373e-6
# V,Δ at center (Nx/2,Ny/2): -0.8747392697069738 0.42675679988316517
# Δ at corner (1,1): 0.4267567998831314
#   0.258512 seconds (7.28 M allocations: 457.466 MiB, 15.24% gc time)
# ite = 11 eps = 5.737999145296661e-7
# End 0.42708006637453444
#   3.649889 seconds (80.11 M allocations: 4.915 GiB, 12.65% gc time)
# --------------------------------------
# Green's function based Full diagonalization
# --------------------------------------
#   0.068084 seconds (466 allocations: 2.211 MiB)
#   0.049727 seconds (299 allocations: 2.200 MiB)
# ite = 1 eps = 0.45576618876810127
# V,Δ at center (Nx/2,Ny/2): -0.7572874834801987 0.16751045761718153
# Δ at corner (1,1): 0.16751045761717975
#   0.049407 seconds (299 allocations: 2.200 MiB)
#   0.053050 seconds (299 allocations: 2.200 MiB)
# ite = 2 eps = 0.2477636698134346
# V,Δ at center (Nx/2,Ny/2): -0.7885201019866362 0.2508902362160619
# Δ at corner (1,1): 0.2508902362160619
#   0.052390 seconds (299 allocations: 2.200 MiB)
#   0.053126 seconds (299 allocations: 2.200 MiB)
# ite = 3 eps = 0.08734339066085038
# V,Δ at center (Nx/2,Ny/2): -0.8248886601295611 0.32503812399806264
# Δ at corner (1,1): 0.3250381239980644
#   0.053682 seconds (299 allocations: 2.200 MiB)
#   0.054843 seconds (299 allocations: 2.200 MiB, 4.18% gc time)
# ite = 4 eps = 0.02273034684818143
# V,Δ at center (Nx/2,Ny/2): -0.8501738616743653 0.3740427787818774
# Δ at corner (1,1): 0.3740427787818774
#   0.055783 seconds (299 allocations: 2.200 MiB)
#   0.053076 seconds (299 allocations: 2.200 MiB)
# ite = 5 eps = 0.005243372510676426
# V,Δ at center (Nx/2,Ny/2): -0.8633238131433132 0.40112764103195
# Δ at corner (1,1): 0.40112764103195
#   0.054440 seconds (299 allocations: 2.200 MiB)
#   0.051086 seconds (299 allocations: 2.200 MiB)
# ite = 6 eps = 0.001164195229678383
# V,Δ at center (Nx/2,Ny/2): -0.8695610880496496 0.41481423858420463
# Δ at corner (1,1): 0.4148142385842064
#   0.052719 seconds (299 allocations: 2.200 MiB)
#   0.054592 seconds (299 allocations: 2.200 MiB)
# ite = 7 eps = 0.00025522707993219076
# V,Δ at center (Nx/2,Ny/2): -0.8724662274591602 0.42144123950718715
# Δ at corner (1,1): 0.4214412395071907
#   0.054499 seconds (299 allocations: 2.200 MiB)
#   0.055707 seconds (299 allocations: 2.200 MiB)
# ite = 8 eps = 5.5687538851635144e-5
# V,Δ at center (Nx/2,Ny/2): -0.8738173289834572 0.42458620614517883
# Δ at corner (1,1): 0.4245862061451806
#   0.065001 seconds (299 allocations: 2.200 MiB, 4.33% gc time)
#   0.052165 seconds (299 allocations: 2.200 MiB)
# ite = 9 eps = 1.2126426584572235e-5
# V,Δ at center (Nx/2,Ny/2): -0.8744462678596079 0.4260647435013212
# Δ at corner (1,1): 0.42606474350132295
#   0.051918 seconds (299 allocations: 2.200 MiB)
#   0.051674 seconds (299 allocations: 2.200 MiB)
# ite = 10 eps = 2.6383460597733984e-6
# V,Δ at center (Nx/2,Ny/2): -0.8747392697066648 0.42675679988315274
# Δ at corner (1,1): 0.42675679988315274
#   0.052142 seconds (299 allocations: 2.200 MiB)
#   0.051484 seconds (299 allocations: 2.200 MiB)
# ite = 11 eps = 5.737999145766079e-7
# End 0.4270800663744492
#   1.259896 seconds (29.87 k allocations: 49.233 MiB, 0.41% gc time)
# --------------------------------------
# Chebyshev method
# --------------------------------------
#   0.022813 seconds (158 allocations: 359.469 KiB)
#   0.022598 seconds (158 allocations: 359.469 KiB)
# ite = 1 eps = 0.49736571435769683
# V,Δ at center (Nx/2,Ny/2): -0.7436479150412671 0.17052415999908807
# Δ at corner (1,1): 0.1705241599990881
#   0.025438 seconds (158 allocations: 359.469 KiB)
#   0.025535 seconds (158 allocations: 359.469 KiB)
# ite = 2 eps = 0.22298357307325653
# V,Δ at center (Nx/2,Ny/2): -0.7877626490325165 0.25104760632850215
# Δ at corner (1,1): 0.25104760632850215
#   0.022940 seconds (158 allocations: 359.469 KiB)
#   0.022133 seconds (158 allocations: 359.469 KiB)
# ite = 3 eps = 0.0758107753423487
# V,Δ at center (Nx/2,Ny/2): -0.8261499600033514 0.3201704432468523
# Δ at corner (1,1): 0.32017044324685223
#   0.022966 seconds (158 allocations: 359.469 KiB)
#   0.025197 seconds (158 allocations: 359.469 KiB)
# ite = 4 eps = 0.019740171275826945
# V,Δ at center (Nx/2,Ny/2): -0.8510175076574115 0.36515430082489064
# Δ at corner (1,1): 0.365154300824891
#   0.024311 seconds (158 allocations: 359.469 KiB)
#   0.023917 seconds (158 allocations: 359.469 KiB)
# ite = 5 eps = 0.007435372366744899
# V,Δ at center (Nx/2,Ny/2): -0.8594630920857562 0.3966410468932265
# Δ at corner (1,1): 0.39664104689322655
#   0.024043 seconds (158 allocations: 359.469 KiB)
#   0.023429 seconds (158 allocations: 359.469 KiB)
# ite = 6 eps = 0.0007274245208779073
# V,Δ at center (Nx/2,Ny/2): -0.8704468143337438 0.40733877668380064
# Δ at corner (1,1): 0.4073387766838007
#   0.023296 seconds (158 allocations: 359.469 KiB)
#   0.023029 seconds (158 allocations: 359.469 KiB)
# ite = 7 eps = 0.00039383294162097357
# V,Δ at center (Nx/2,Ny/2): -0.8715843339358876 0.41542250621792254
# Δ at corner (1,1): 0.41542250621792254
#   0.022837 seconds (158 allocations: 359.469 KiB)
#   0.022948 seconds (158 allocations: 359.469 KiB)
# ite = 8 eps = 0.00024390852041951267
# V,Δ at center (Nx/2,Ny/2): -0.8721347269786264 0.42191039665695657
# Δ at corner (1,1): 0.42191039665695657
#   0.023586 seconds (158 allocations: 359.469 KiB)
#   0.023449 seconds (158 allocations: 359.469 KiB)
# ite = 9 eps = 0.00011358256453294872
# V,Δ at center (Nx/2,Ny/2): -0.8728174004329029 0.4264069118217934
# Δ at corner (1,1): 0.4264069118217932
#   0.023420 seconds (158 allocations: 359.469 KiB)
#   0.023812 seconds (158 allocations: 359.469 KiB)
# ite = 10 eps = 3.3630321991115304e-5
# V,Δ at center (Nx/2,Ny/2): -0.8735298756172578 0.4288797161287447
# Δ at corner (1,1): 0.4288797161287445
#   0.023345 seconds (158 allocations: 359.469 KiB)
#   0.025510 seconds (158 allocations: 359.469 KiB)
# ite = 11 eps = 6.662439785894919e-6
# V,Δ at center (Nx/2,Ny/2): -0.8740142498617032 0.429986727686731
# Δ at corner (1,1): 0.4299867276867305
#   0.023051 seconds (158 allocations: 359.469 KiB)
#   0.023388 seconds (158 allocations: 359.469 KiB)
# ite = 12 eps = 1.0369959584623516e-6
# V,Δ at center (Nx/2,Ny/2): -0.8742516284716 0.43042459606470995
# Δ at corner (1,1): 0.43042459606470973
#   0.023578 seconds (158 allocations: 359.469 KiB)
#   0.022193 seconds (158 allocations: 359.469 KiB)
# ite = 13 eps = 1.4446997175867192e-7
# End 0.43058819703479156
#   0.693059 seconds (25.61 k allocations: 9.803 MiB)
# --------------------------------------
# Full diagonalization
# --------------------------------------
#   0.008721 seconds (23.38 k allocations: 576.766 KiB)
#   0.010711 seconds (23.38 k allocations: 576.766 KiB, 18.32% gc time)
# ite = 1 eps = 0.4525485083630871
# V,Δ at center (Nx/2,Ny/2): -0.7509990048474185 0.16727172573697693
# Δ at corner (1,1): 0.16727172573697538
#   0.008890 seconds (23.38 k allocations: 576.766 KiB)
#   0.008824 seconds (23.38 k allocations: 576.766 KiB)
# ite = 2 eps = 0.243111612266087
# V,Δ at center (Nx/2,Ny/2): -0.7854265731469382 0.24974730781068052
# Δ at corner (1,1): 0.24974730781067847
#   0.009418 seconds (23.38 k allocations: 576.766 KiB)
#   0.009008 seconds (23.38 k allocations: 576.766 KiB)
# ite = 3 eps = 0.08454136146553184
# V,Δ at center (Nx/2,Ny/2): -0.8231907619019254 0.32236382810038816
# Δ at corner (1,1): 0.3223638281003882
#   0.008560 seconds (23.38 k allocations: 576.766 KiB)
#   0.008934 seconds (23.38 k allocations: 576.766 KiB)
# ite = 4 eps = 0.022213656501945532
# V,Δ at center (Nx/2,Ny/2): -0.8485551551125057 0.3704097278064538
# Δ at corner (1,1): 0.3704097278064557
#   0.009865 seconds (23.38 k allocations: 576.766 KiB)
#   0.008520 seconds (23.38 k allocations: 576.766 KiB)
# ite = 5 eps = 0.005233650629665319
# V,Δ at center (Nx/2,Ny/2): -0.8616999316361398 0.39720663966644887
# Δ at corner (1,1): 0.397206639666451
#   0.008784 seconds (23.38 k allocations: 576.766 KiB)
#   0.008773 seconds (23.38 k allocations: 576.766 KiB)
# ite = 6 eps = 0.0011902460823770568
# V,Δ at center (Nx/2,Ny/2): -0.8679885092027415 0.4109102461826654
# Δ at corner (1,1): 0.41091024618266664
#   0.010167 seconds (23.38 k allocations: 576.766 KiB)
#   0.009342 seconds (23.38 k allocations: 576.766 KiB)
# ite = 7 eps = 0.0002674336961584428
# V,Δ at center (Nx/2,Ny/2): -0.8709509598780694 0.4176300258603627
# Δ at corner (1,1): 0.41763002586036213
#   0.008892 seconds (23.38 k allocations: 576.766 KiB)
#   0.009011 seconds (23.38 k allocations: 576.766 KiB)
# ite = 8 eps = 5.981077956605962e-5
# V,Δ at center (Nx/2,Ny/2): -0.8723452978842645 0.4208598691163997
# Δ at corner (1,1): 0.42085986911640133
#   0.008642 seconds (23.38 k allocations: 576.766 KiB)
#   0.008227 seconds (23.38 k allocations: 576.766 KiB)
# ite = 9 eps = 1.335040545545317e-5
# V,Δ at center (Nx/2,Ny/2): -0.8730023055500639 0.42239761560344496
# Δ at corner (1,1): 0.42239761560344796
#   0.008460 seconds (23.38 k allocations: 576.766 KiB)
#   0.008391 seconds (23.38 k allocations: 576.766 KiB)
# ite = 10 eps = 2.9773638000091366e-6
# V,Δ at center (Nx/2,Ny/2): -0.8733121569068066 0.42312646434766976
# Δ at corner (1,1): 0.423126464347672
#   0.008591 seconds (23.38 k allocations: 576.766 KiB)
#   0.008353 seconds (23.38 k allocations: 576.766 KiB)
# ite = 11 eps = 6.637372921524073e-7
# End 0.42347118579035364
#   0.274199 seconds (532.09 k allocations: 12.910 MiB, 0.72% gc time)
# --------------------------------------
# -----------Summary           ---------
# --------------------------------------
# Interaction U: -2.0
# Chemical potential: -0.2
# Imaginary axis methods
# Cutoff: 188.49555921538757 i
# Temperature: 0.05
# RSCG: center V,Δ at (Nx/2,Ny/2): -0.8748758302892883 0.42675679988316517
# Full: center V,Δ at (Nx/2,Ny/2): -0.8748758302891465 0.42675679988315274
# Real axis methods
# Cutoff: 10.0
# Temperature: zero
# Chebyshev with nc=1000: center V,Δ at (Nx/2,Ny/2): -0.874348866203227 0.43042459606470995
# Full: center V,Δ at(Nx/2,Ny/2): -0.8734583577925489 0.42312646434766976
# --------------------------------------
# All done.

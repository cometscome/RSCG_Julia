# %% [markdown]
# # RSCG method and Chebyshev polynomial method
# We consider the tight-binding model with s-wave superconducting gap.
#
# We solve the Bogoloiubov-de Gennes equations with gap equations self-consistently.

# %%
include("ChevplusRSCG.jl")
using ChevplusRSCG

Hartree = false
nc = 1000 #Number of Chebyshev polynomials that we consider
Nx = 6 #System size
Ny = 6 #System size
aa = 10.0 #Chebyshev renormalize parameter
bb = 0.0
ωc = 10.0 #Cutoff energy
U = -2.0 #Interaction
initialΔ = 0.1 #Initial guess for the superconducting gap
μ = -0.2 #Chemical potential
finite = true

T = 0.05 #We use T only in the case of RSCG
omegamax = 60π #Parameter for RSCG. This is a cutoff on the imaginary Matsubra axis
println("--------------------------------------")
println("RSCG method")
println("--------------------------------------")
full = false #Full diagonalization or not
RSCG = true
itemax = 20
@time mat_Δ1,HF1 = ChevplusRSCG.iteration(nc,Nx,Ny,aa,bb,ωc,U,initialΔ,μ,full,RSCG,finite,T,Hartree,omegamax,itemax)
println("--------------------------------------")
println("Green's function based Full diagonalization ")
println("--------------------------------------")
full = true #Full diagonalization or not
finite == true
itemax = 20
@time mat_Δ2,HF2 = ChevplusRSCG.iteration(nc,Nx,Ny,aa,bb,ωc,U,initialΔ,μ,full,RSCG,finite,T,Hartree,omegamax,itemax)


println("--------------------------------------")
println("Chebyshev method")
println("--------------------------------------")
full = false #Full diagonalization or not
RSCG = false
itemax = 20
@time mat_Δ3,HF3 = ChevplusRSCG.iteration(nc,Nx,Ny,aa,bb,ωc,U,initialΔ,μ,full,RSCG,finite,T,Hartree,omegamax,itemax)
println("--------------------------------------")
println("Full diagonalization")
println("--------------------------------------")
full = true #Full diagonalization or not
finite = false
itemax = 20
@time mat_Δ4,HF4 = ChevplusRSCG.iteration(nc,Nx,Ny,aa,bb,ωc,U,initialΔ,μ,full,RSCG,finite,T,Hartree,omegamax,itemax)

println("--------------------------------------")
println("-----------Summary           ---------")
println("--------------------------------------")
println("Interaction U: ",U)
println("Chemical potential: ",μ)
println("Imaginary axis methods")
println("Cutoff: ",omegamax," i")
println("Temperature: ", T)
println("RSCG: center V,Δ at (Nx/2,Ny/2): ",HF1[div(Nx,2),div(Ny,2)]," ",mat_Δ1[div(Nx,2),div(Ny,2)])
println("Full: center V,Δ at (Nx/2,Ny/2): ",HF2[div(Nx,2),div(Ny,2)]," ", mat_Δ2[div(Nx,2),div(Ny,2)])

println("Real axis methods")
println("Cutoff: ",ωc)
println("Temperature: zero")
println("Chebyshev with nc=",nc,": center V,Δ at (Nx/2,Ny/2): ",HF3[div(Nx,2),div(Ny,2)]," ",mat_Δ3[div(Nx,2),div(Ny,2)])
println("Full: center V,Δ at(Nx/2,Ny/2): ",HF4[div(Nx,2),div(Ny,2)]," ", mat_Δ4[div(Nx,2),div(Ny,2)])
println("--------------------------------------")
println("All done.")
# Out:
# --------------------------------------
# RSCG method
# --------------------------------------
# WARNING: replacing module chebyshev
# WARNING: replacing module rscg
# WARNING: replacing module ChevplusRSCG
#   0.209729 seconds (22.59 k allocations: 21.268 MiB, 4.74% gc time)
# ite = 1 eps = 0.4557661887681019
# Δ at center (Nx/2,Ny/2): 0.16751045761717975
# Δ at corner (1,1): 0.16751045761717975
#   0.188129 seconds (22.59 k allocations: 21.268 MiB, 2.87% gc time)
# ite = 2 eps = 0.247763669813432
# Δ at center (Nx/2,Ny/2): 0.2508902362160601
# Δ at corner (1,1): 0.2508902362160601
#   0.175704 seconds (22.59 k allocations: 21.268 MiB, 1.58% gc time)
# ite = 3 eps = 0.08734339066085015
# Δ at center (Nx/2,Ny/2): 0.32503812399806264
# Δ at corner (1,1): 0.32503812399806264
#   0.176279 seconds (22.59 k allocations: 21.268 MiB, 1.16% gc time)
# ite = 4 eps = 0.022730346848181784
# Δ at center (Nx/2,Ny/2): 0.3740427787818774
# Δ at corner (1,1): 0.3740427787818774
#   0.187708 seconds (22.59 k allocations: 21.268 MiB, 0.48% gc time)
# ite = 5 eps = 0.005243372510676471
# Δ at center (Nx/2,Ny/2): 0.40112764103195
# Δ at corner (1,1): 0.40112764103195
#   0.176346 seconds (22.59 k allocations: 21.268 MiB, 0.53% gc time)
# ite = 6 eps = 0.001164195229678451
# Δ at center (Nx/2,Ny/2): 0.4148142385842064
# Δ at corner (1,1): 0.4148142385842064
#   0.178220 seconds (22.59 k allocations: 21.268 MiB, 0.50% gc time)
# ite = 7 eps = 0.00025522707993219055
# Δ at center (Nx/2,Ny/2): 0.4214412395071907
# Δ at corner (1,1): 0.4214412395071907
#   0.188111 seconds (22.59 k allocations: 21.268 MiB, 0.58% gc time)
# ite = 8 eps = 5.5687538851633335e-5
# Δ at center (Nx/2,Ny/2): 0.4245862061451806
# Δ at corner (1,1): 0.4245862061451806
#   0.179896 seconds (22.59 k allocations: 21.268 MiB, 0.58% gc time)
# ite = 9 eps = 1.2126426584570611e-5
# Δ at center (Nx/2,Ny/2): 0.42606474350132295
# Δ at corner (1,1): 0.42606474350132295
#   0.170918 seconds (22.59 k allocations: 21.268 MiB, 0.54% gc time)
# ite = 10 eps = 2.6383460597722693e-6
# Δ at center (Nx/2,Ny/2): 0.42675679988315274
# Δ at corner (1,1): 0.42675679988315274
#   0.190465 seconds (22.59 k allocations: 21.268 MiB, 0.51% gc time)
# ite = 11 eps = 5.737999145725792e-7
# End 0.4270800663744492
#   3.935396 seconds (1.39 M allocations: 293.166 MiB, 1.38% gc time)
# --------------------------------------
# Green's function based Full diagonalization
# --------------------------------------
#   0.274382 seconds (24.53 k allocations: 3.293 MiB)
# ite = 1 eps = 0.45576618876810127
# Δ at center (Nx/2,Ny/2): 0.16751045761718153
# Δ at corner (1,1): 0.16751045761717975
#   0.051043 seconds (299 allocations: 2.200 MiB)
# ite = 2 eps = 0.24776366981343115
# Δ at center (Nx/2,Ny/2): 0.2508902362160583
# Δ at corner (1,1): 0.2508902362160619
#   0.049880 seconds (299 allocations: 2.200 MiB)
# ite = 3 eps = 0.08734339066085091
# Δ at center (Nx/2,Ny/2): 0.32503812399806087
# Δ at corner (1,1): 0.32503812399806264
#   0.050611 seconds (299 allocations: 2.200 MiB)
# ite = 4 eps = 0.022730346848182276
# Δ at center (Nx/2,Ny/2): 0.3740427787818774
# Δ at corner (1,1): 0.3740427787818774
#   0.048776 seconds (299 allocations: 2.200 MiB)
# ite = 5 eps = 0.005243372510676264
# Δ at center (Nx/2,Ny/2): 0.40112764103195
# Δ at corner (1,1): 0.40112764103195
#   0.054970 seconds (299 allocations: 2.200 MiB, 4.26% gc time)
# ite = 6 eps = 0.0011641952296784423
# Δ at center (Nx/2,Ny/2): 0.41481423858420463
# Δ at corner (1,1): 0.4148142385842064
#   0.051043 seconds (299 allocations: 2.200 MiB)
# ite = 7 eps = 0.0002552270799321791
# Δ at center (Nx/2,Ny/2): 0.42144123950718715
# Δ at corner (1,1): 0.4214412395071907
#   0.053002 seconds (299 allocations: 2.200 MiB)
# ite = 8 eps = 5.568753885163511e-5
# Δ at center (Nx/2,Ny/2): 0.42458620614517883
# Δ at corner (1,1): 0.4245862061451806
#   0.053995 seconds (299 allocations: 2.200 MiB)
# ite = 9 eps = 1.2126426584570614e-5
# Δ at center (Nx/2,Ny/2): 0.4260647435013212
# Δ at corner (1,1): 0.42606474350132295
#   0.052851 seconds (299 allocations: 2.200 MiB)
# ite = 10 eps = 2.638346059772646e-6
# Δ at center (Nx/2,Ny/2): 0.42675679988315274
# Δ at corner (1,1): 0.42675679988315274
#   0.054837 seconds (299 allocations: 2.200 MiB)
# ite = 11 eps = 5.737999145769584e-7
# End 0.4270800663744492
#   0.863477 seconds (46.21 k allocations: 26.019 MiB, 0.27% gc time)
# --------------------------------------
# Chebyshev method
# --------------------------------------
#   0.022396 seconds (158 allocations: 359.469 KiB)
# ite = 1 eps = 0.49736571435769683
# Δ at center (Nx/2,Ny/2): 0.17052415999908807
# Δ at corner (1,1): 0.1705241599990881
#   0.021637 seconds (158 allocations: 359.469 KiB)
# ite = 2 eps = 0.22298357307325659
# Δ at center (Nx/2,Ny/2): 0.2510476063285021
# Δ at corner (1,1): 0.2510476063285022
#   0.022036 seconds (158 allocations: 359.469 KiB)
# ite = 3 eps = 0.07581077534234876
# Δ at center (Nx/2,Ny/2): 0.3201704432468523
# Δ at corner (1,1): 0.3201704432468525
#   0.021791 seconds (158 allocations: 359.469 KiB)
# ite = 4 eps = 0.01974017127582697
# Δ at center (Nx/2,Ny/2): 0.365154300824891
# Δ at corner (1,1): 0.365154300824891
#   0.023013 seconds (158 allocations: 359.469 KiB)
# ite = 5 eps = 0.007435372366744903
# Δ at center (Nx/2,Ny/2): 0.3966410468932268
# Δ at corner (1,1): 0.3966410468932265
#   0.022810 seconds (158 allocations: 359.469 KiB)
# ite = 6 eps = 0.0007274245208779288
# Δ at center (Nx/2,Ny/2): 0.40733877668380075
# Δ at corner (1,1): 0.40733877668380086
#   0.024124 seconds (158 allocations: 359.469 KiB)
# ite = 7 eps = 0.00039383294162095167
# Δ at center (Nx/2,Ny/2): 0.4154225062179223
# Δ at corner (1,1): 0.41542250621792276
#   0.021589 seconds (158 allocations: 359.469 KiB)
# ite = 8 eps = 0.0002439085204195122
# Δ at center (Nx/2,Ny/2): 0.4219103966569563
# Δ at corner (1,1): 0.42191039665695623
#   0.023211 seconds (158 allocations: 359.469 KiB)
# ite = 9 eps = 0.00011358256453294197
# Δ at center (Nx/2,Ny/2): 0.4264069118217937
# Δ at corner (1,1): 0.42640691182179324
#   0.023235 seconds (158 allocations: 359.469 KiB)
# ite = 10 eps = 3.363032199111385e-5
# Δ at center (Nx/2,Ny/2): 0.42887971612874476
# Δ at corner (1,1): 0.42887971612874476
#   0.022449 seconds (158 allocations: 359.469 KiB)
# ite = 11 eps = 6.66243978590292e-6
# Δ at center (Nx/2,Ny/2): 0.42998672768673096
# Δ at corner (1,1): 0.4299867276867311
#   0.023080 seconds (158 allocations: 359.469 KiB)
# ite = 12 eps = 1.0369959584634369e-6
# Δ at center (Nx/2,Ny/2): 0.43042459606471073
# Δ at corner (1,1): 0.43042459606471084
#   0.023546 seconds (158 allocations: 359.469 KiB)
# ite = 13 eps = 1.4446997175802876e-7
# End 0.43058819703479173
#   0.357018 seconds (16.02 k allocations: 9.005 MiB)
# --------------------------------------
# Full diagonalization
# --------------------------------------
#   0.014380 seconds (23.40 k allocations: 578.250 KiB)
# ite = 1 eps = 0.4525485083630871
# Δ at center (Nx/2,Ny/2): 0.16727172573697693
# Δ at corner (1,1): 0.16727172573697538
#   0.017030 seconds (23.38 k allocations: 576.766 KiB, 44.09% gc time)
# ite = 2 eps = 0.2431116122660842
# Δ at center (Nx/2,Ny/2): 0.2497473078106768
# Δ at corner (1,1): 0.24974730781067825
#   0.009415 seconds (23.38 k allocations: 576.766 KiB)
# ite = 3 eps = 0.08454136146553266
# Δ at center (Nx/2,Ny/2): 0.32236382810038866
# Δ at corner (1,1): 0.3223638281003879
#   0.009185 seconds (23.38 k allocations: 576.766 KiB)
# ite = 4 eps = 0.022213656501945594
# Δ at center (Nx/2,Ny/2): 0.37040972780645376
# Δ at corner (1,1): 0.37040972780645587
#   0.009951 seconds (23.38 k allocations: 576.766 KiB)
# ite = 5 eps = 0.005233650629665356
# Δ at center (Nx/2,Ny/2): 0.3972066396664507
# Δ at corner (1,1): 0.3972066396664508
#   0.009435 seconds (23.38 k allocations: 576.766 KiB)
# ite = 6 eps = 0.0011902460823770662
# Δ at center (Nx/2,Ny/2): 0.41091024618266453
# Δ at corner (1,1): 0.410910246182666
#   0.010059 seconds (23.38 k allocations: 576.766 KiB)
# ite = 7 eps = 0.00026743369615844
# Δ at center (Nx/2,Ny/2): 0.4176300258603594
# Δ at corner (1,1): 0.417630025860362
#   0.009265 seconds (23.38 k allocations: 576.766 KiB)
# ite = 8 eps = 5.9810779566057905e-5
# Δ at center (Nx/2,Ny/2): 0.4208598691163989
# Δ at corner (1,1): 0.4208598691164016
#   0.009133 seconds (23.38 k allocations: 576.766 KiB)
# ite = 9 eps = 1.3350405455456984e-5
# Δ at center (Nx/2,Ny/2): 0.4223976156034459
# Δ at corner (1,1): 0.42239761560344824
#   0.009211 seconds (23.38 k allocations: 576.766 KiB)
# ite = 10 eps = 2.977363800008948e-6
# Δ at center (Nx/2,Ny/2): 0.42312646434767065
# Δ at corner (1,1): 0.4231264643476726
#   0.009248 seconds (23.38 k allocations: 576.766 KiB)
# ite = 11 eps = 6.637372921527579e-7
# End 0.4234711857903541
#   0.181435 seconds (267.61 k allocations: 6.516 MiB, 4.14% gc time)
# --------------------------------------
# -----------Summary           ---------
# --------------------------------------
# Interaction U: -2.0
# Chemical potential: -0.2
# Imaginary axis methods
# Cutoff: 188.49555921538757 i
# Temperature: 0.05
# RSCG: center V,Δ at (Nx/2,Ny/2): 0.0 0.42675679988315274
# Full: center V,Δ at (Nx/2,Ny/2): 0.0 0.42675679988315274
# Real axis methods
# Cutoff: 10.0
# Temperature: zero
# Chebyshev with nc=1000: center V,Δ at (Nx/2,Ny/2): 0.0 0.43042459606471073
# Full: center V,Δ at(Nx/2,Ny/2): 0.0 0.42312646434767065
# --------------------------------------
# All done.

# %% [markdown]
# Add Hartree term.
#
# We can calculate the Hartree and gap simultaneously. But, in this code, we calculate these seperately.

# %%
include("ChevplusRSCG.jl")
using ChevplusRSCG

Hartree = true
nc = 1000 #Number of Chebyshev polynomials that we consider
Nx = 6 #System size
Ny = 6 #System size
aa = 10.0 #Chebyshev renormalize parameter
bb = 0.0
ωc = 10.0 #Cutoff energy
U = -2.0 #Interaction
initialΔ = 0.1 #Initial guess for the superconducting gap
μ = -0.2 #Chemical potential
finite = true

T = 0.05 #We use T only in the case of RSCG
omegamax = 60π #Parameter for RSCG. This is a cutoff on the imaginary Matsubra axis
println("--------------------------------------")
println("RSCG method")
println("--------------------------------------")
full = false #Full diagonalization or not
RSCG = true
itemax = 20
@time mat_Δ1,HF1 = ChevplusRSCG.iteration(nc,Nx,Ny,aa,bb,ωc,U,initialΔ,μ,full,RSCG,finite,T,Hartree,omegamax,itemax)
println("--------------------------------------")
println("Green's function based Full diagonalization ")
println("--------------------------------------")
full = true #Full diagonalization or not
finite == true
itemax = 20
@time mat_Δ2,HF2 = ChevplusRSCG.iteration(nc,Nx,Ny,aa,bb,ωc,U,initialΔ,μ,full,RSCG,finite,T,Hartree,omegamax,itemax)


println("--------------------------------------")
println("Chebyshev method")
println("--------------------------------------")
full = false #Full diagonalization or not
RSCG = false
itemax = 20
@time mat_Δ3,HF3 = ChevplusRSCG.iteration(nc,Nx,Ny,aa,bb,ωc,U,initialΔ,μ,full,RSCG,finite,T,Hartree,omegamax,itemax)
println("--------------------------------------")
println("Full diagonalization")
println("--------------------------------------")
full = true #Full diagonalization or not
finite = false
itemax = 20
@time mat_Δ4,HF4 = ChevplusRSCG.iteration(nc,Nx,Ny,aa,bb,ωc,U,initialΔ,μ,full,RSCG,finite,T,Hartree,omegamax,itemax)

println("--------------------------------------")
println("-----------Summary           ---------")
println("--------------------------------------")
println("Interaction U: ",U)
println("Chemical potential: ",μ)
println("Imaginary axis methods")
println("Cutoff: ",omegamax," i")
println("Temperature: ", T)
println("RSCG: center V,Δ at (Nx/2,Ny/2): ",HF1[div(Nx,2),div(Ny,2)]," ",mat_Δ1[div(Nx,2),div(Ny,2)])
println("Full: center V,Δ at (Nx/2,Ny/2): ",HF2[div(Nx,2),div(Ny,2)]," ", mat_Δ2[div(Nx,2),div(Ny,2)])

println("Real axis methods")
println("Cutoff: ",ωc)
println("Temperature: zero")
println("Chebyshev with nc=",nc,": center V,Δ at (Nx/2,Ny/2): ",HF3[div(Nx,2),div(Ny,2)]," ",mat_Δ3[div(Nx,2),div(Ny,2)])
println("Full: center V,Δ at(Nx/2,Ny/2): ",HF4[div(Nx,2),div(Ny,2)]," ", mat_Δ4[div(Nx,2),div(Ny,2)])
println("--------------------------------------")
println("All done.")
# Out:
# --------------------------------------
# RSCG method
# --------------------------------------
# WARNING: replacing module chebyshev
# WARNING: replacing module rscg
# WARNING: replacing module ChevplusRSCG
#   0.181580 seconds (22.59 k allocations: 21.268 MiB, 3.92% gc time)
#   0.183144 seconds (22.59 k allocations: 21.268 MiB, 3.24% gc time)
# ite = 1 eps = 0.4557661887681019
# V,Δ at center (Nx/2,Ny/2): -0.7572874834801989 0.16751045761717975
# Δ at corner (1,1): 0.16751045761717975
#   0.176787 seconds (22.59 k allocations: 21.268 MiB, 1.59% gc time)
#   0.179855 seconds (22.59 k allocations: 21.268 MiB, 1.20% gc time)
# ite = 2 eps = 0.24776366981343229
# V,Δ at center (Nx/2,Ny/2): -0.7885201019866364 0.2508902362160601
# Δ at corner (1,1): 0.2508902362160601
#   0.180823 seconds (22.59 k allocations: 21.268 MiB, 1.72% gc time)
#   0.178719 seconds (22.59 k allocations: 21.268 MiB, 0.73% gc time)
# ite = 3 eps = 0.08734339066085
# V,Δ at center (Nx/2,Ny/2): -0.8248886601295603 0.32503812399806264
# Δ at corner (1,1): 0.32503812399806264
#   0.175274 seconds (22.59 k allocations: 21.268 MiB, 0.84% gc time)
#   0.170189 seconds (22.59 k allocations: 21.268 MiB, 0.72% gc time)
# ite = 4 eps = 0.022730346848181784
# V,Δ at center (Nx/2,Ny/2): -0.8501738616743646 0.3740427787818774
# Δ at corner (1,1): 0.3740427787818774
#   0.177477 seconds (22.59 k allocations: 21.268 MiB, 0.70% gc time)
#   0.174432 seconds (22.59 k allocations: 21.268 MiB, 1.04% gc time)
# ite = 5 eps = 0.005243372510676471
# V,Δ at center (Nx/2,Ny/2): -0.8633238131433119 0.40112764103195
# Δ at corner (1,1): 0.40112764103195
#   0.171778 seconds (22.59 k allocations: 21.268 MiB, 0.76% gc time)
#   0.184380 seconds (22.59 k allocations: 21.268 MiB, 0.81% gc time)
# ite = 6 eps = 0.001164195229678451
# V,Δ at center (Nx/2,Ny/2): -0.8695610880496476 0.4148142385842064
# Δ at corner (1,1): 0.4148142385842064
#   0.175596 seconds (22.59 k allocations: 21.268 MiB, 0.75% gc time)
#   0.171780 seconds (22.59 k allocations: 21.268 MiB, 0.72% gc time)
# ite = 7 eps = 0.00025522707993219055
# V,Δ at center (Nx/2,Ny/2): -0.8724662274591609 0.4214412395071907
# Δ at corner (1,1): 0.4214412395071907
#   0.172508 seconds (22.59 k allocations: 21.268 MiB, 0.71% gc time)
#   0.178888 seconds (22.59 k allocations: 21.268 MiB, 0.81% gc time)
# ite = 8 eps = 5.5687538851633335e-5
# V,Δ at center (Nx/2,Ny/2): -0.8738173289834574 0.4245862061451806
# Δ at corner (1,1): 0.4245862061451806
#   0.177744 seconds (22.59 k allocations: 21.268 MiB, 0.71% gc time)
#   0.174283 seconds (22.59 k allocations: 21.268 MiB, 0.74% gc time)
# ite = 9 eps = 1.2126426584570611e-5
# V,Δ at center (Nx/2,Ny/2): -0.8744462678596078 0.42606474350132295
# Δ at corner (1,1): 0.42606474350132295
#   0.187602 seconds (22.59 k allocations: 21.268 MiB, 0.77% gc time)
#   0.172334 seconds (22.59 k allocations: 21.268 MiB, 0.85% gc time)
# ite = 10 eps = 2.6383460597722693e-6
# V,Δ at center (Nx/2,Ny/2): -0.874739269706667 0.42675679988315274
# Δ at corner (1,1): 0.42675679988315274
#   0.173572 seconds (22.59 k allocations: 21.268 MiB, 0.69% gc time)
#   0.173726 seconds (22.59 k allocations: 21.268 MiB, 0.71% gc time)
# ite = 11 eps = 5.737999145724039e-7
# End 0.4270800663744474
#   4.530638 seconds (763.53 k allocations: 480.449 MiB, 0.97% gc time)
# --------------------------------------
# Green's function based Full diagonalization
# --------------------------------------
#   0.064115 seconds (466 allocations: 2.211 MiB)
#   0.050437 seconds (299 allocations: 2.200 MiB)
# ite = 1 eps = 0.45576618876810127
# V,Δ at center (Nx/2,Ny/2): -0.7572874834801987 0.16751045761718153
# Δ at corner (1,1): 0.16751045761717975
#   0.050405 seconds (299 allocations: 2.200 MiB)
#   0.051114 seconds (299 allocations: 2.200 MiB)
# ite = 2 eps = 0.2477636698134346
# V,Δ at center (Nx/2,Ny/2): -0.7885201019866362 0.2508902362160619
# Δ at corner (1,1): 0.2508902362160619
#   0.049479 seconds (299 allocations: 2.200 MiB)
#   0.048869 seconds (299 allocations: 2.200 MiB)
# ite = 3 eps = 0.08734339066085038
# V,Δ at center (Nx/2,Ny/2): -0.8248886601295611 0.32503812399806264
# Δ at corner (1,1): 0.3250381239980644
#   0.050305 seconds (299 allocations: 2.200 MiB, 3.22% gc time)
#   0.049838 seconds (299 allocations: 2.200 MiB)
# ite = 4 eps = 0.02273034684818143
# V,Δ at center (Nx/2,Ny/2): -0.8501738616743653 0.3740427787818774
# Δ at corner (1,1): 0.3740427787818774
#   0.051177 seconds (299 allocations: 2.200 MiB)
#   0.050816 seconds (299 allocations: 2.200 MiB)
# ite = 5 eps = 0.005243372510676426
# V,Δ at center (Nx/2,Ny/2): -0.8633238131433132 0.40112764103195
# Δ at corner (1,1): 0.40112764103195
#   0.049002 seconds (299 allocations: 2.200 MiB)
#   0.049005 seconds (299 allocations: 2.200 MiB)
# ite = 6 eps = 0.001164195229678383
# V,Δ at center (Nx/2,Ny/2): -0.8695610880496496 0.41481423858420463
# Δ at corner (1,1): 0.4148142385842064
#   0.050884 seconds (299 allocations: 2.200 MiB)
#   0.050124 seconds (299 allocations: 2.200 MiB)
# ite = 7 eps = 0.00025522707993219076
# V,Δ at center (Nx/2,Ny/2): -0.8724662274591602 0.42144123950718715
# Δ at corner (1,1): 0.4214412395071907
#   0.051127 seconds (299 allocations: 2.200 MiB)
#   0.054003 seconds (299 allocations: 2.200 MiB)
# ite = 8 eps = 5.5687538851635144e-5
# V,Δ at center (Nx/2,Ny/2): -0.8738173289834572 0.42458620614517883
# Δ at corner (1,1): 0.4245862061451806
#   0.053981 seconds (299 allocations: 2.200 MiB, 2.76% gc time)
#   0.050492 seconds (299 allocations: 2.200 MiB)
# ite = 9 eps = 1.2126426584572235e-5
# V,Δ at center (Nx/2,Ny/2): -0.8744462678596079 0.4260647435013212
# Δ at corner (1,1): 0.42606474350132295
#   0.052489 seconds (299 allocations: 2.200 MiB)
#   0.050849 seconds (299 allocations: 2.200 MiB)
# ite = 10 eps = 2.6383460597733984e-6
# V,Δ at center (Nx/2,Ny/2): -0.8747392697066648 0.42675679988315274
# Δ at corner (1,1): 0.42675679988315274
#   0.051144 seconds (299 allocations: 2.200 MiB)
#   0.050658 seconds (299 allocations: 2.200 MiB)
# ite = 11 eps = 5.737999145766079e-7
# End 0.4270800663744492
#   1.208269 seconds (29.82 k allocations: 49.232 MiB, 0.26% gc time)
# --------------------------------------
# Chebyshev method
# --------------------------------------
#   0.022444 seconds (158 allocations: 359.469 KiB)
#   0.021231 seconds (158 allocations: 359.469 KiB)
# ite = 1 eps = 0.49736571435769683
# V,Δ at center (Nx/2,Ny/2): -0.7436479150412671 0.17052415999908807
# Δ at corner (1,1): 0.1705241599990881
#   0.021535 seconds (158 allocations: 359.469 KiB)
#   0.021282 seconds (158 allocations: 359.469 KiB)
# ite = 2 eps = 0.22298357307325653
# V,Δ at center (Nx/2,Ny/2): -0.7877626490325165 0.25104760632850215
# Δ at corner (1,1): 0.25104760632850215
#   0.021845 seconds (158 allocations: 359.469 KiB)
#   0.021564 seconds (158 allocations: 359.469 KiB)
# ite = 3 eps = 0.0758107753423487
# V,Δ at center (Nx/2,Ny/2): -0.8261499600033514 0.3201704432468523
# Δ at corner (1,1): 0.32017044324685223
#   0.021271 seconds (158 allocations: 359.469 KiB)
#   0.021252 seconds (158 allocations: 359.469 KiB)
# ite = 4 eps = 0.019740171275826945
# V,Δ at center (Nx/2,Ny/2): -0.8510175076574115 0.36515430082489064
# Δ at corner (1,1): 0.365154300824891
#   0.022104 seconds (158 allocations: 359.469 KiB)
#   0.022622 seconds (158 allocations: 359.469 KiB)
# ite = 5 eps = 0.007435372366744899
# V,Δ at center (Nx/2,Ny/2): -0.8594630920857562 0.3966410468932265
# Δ at corner (1,1): 0.39664104689322655
#   0.022045 seconds (158 allocations: 359.469 KiB)
#   0.021352 seconds (158 allocations: 359.469 KiB)
# ite = 6 eps = 0.0007274245208779073
# V,Δ at center (Nx/2,Ny/2): -0.8704468143337438 0.40733877668380064
# Δ at corner (1,1): 0.4073387766838007
#   0.021471 seconds (158 allocations: 359.469 KiB)
#   0.021934 seconds (158 allocations: 359.469 KiB)
# ite = 7 eps = 0.00039383294162097357
# V,Δ at center (Nx/2,Ny/2): -0.8715843339358876 0.41542250621792254
# Δ at corner (1,1): 0.41542250621792254
#   0.021362 seconds (158 allocations: 359.469 KiB)
#   0.021334 seconds (158 allocations: 359.469 KiB)
# ite = 8 eps = 0.00024390852041951267
# V,Δ at center (Nx/2,Ny/2): -0.8721347269786264 0.42191039665695657
# Δ at corner (1,1): 0.42191039665695657
#   0.021445 seconds (158 allocations: 359.469 KiB)
#   0.023705 seconds (158 allocations: 359.469 KiB)
# ite = 9 eps = 0.00011358256453294872
# V,Δ at center (Nx/2,Ny/2): -0.8728174004329029 0.4264069118217934
# Δ at corner (1,1): 0.4264069118217932
#   0.023941 seconds (158 allocations: 359.469 KiB)
#   0.022139 seconds (158 allocations: 359.469 KiB)
# ite = 10 eps = 3.3630321991115304e-5
# V,Δ at center (Nx/2,Ny/2): -0.8735298756172578 0.4288797161287447
# Δ at corner (1,1): 0.4288797161287445
#   0.021918 seconds (158 allocations: 359.469 KiB)
#   0.023073 seconds (158 allocations: 359.469 KiB)
# ite = 11 eps = 6.662439785894919e-6
# V,Δ at center (Nx/2,Ny/2): -0.8740142498617032 0.429986727686731
# Δ at corner (1,1): 0.4299867276867305
#   0.021597 seconds (158 allocations: 359.469 KiB)
#   0.021133 seconds (158 allocations: 359.469 KiB)
# ite = 12 eps = 1.0369959584623516e-6
# V,Δ at center (Nx/2,Ny/2): -0.8742516284716 0.43042459606470995
# Δ at corner (1,1): 0.43042459606470973
#   0.023257 seconds (158 allocations: 359.469 KiB, 6.88% gc time)
#   0.022401 seconds (158 allocations: 359.469 KiB)
# ite = 13 eps = 1.4446997175867192e-7
# End 0.43058819703479156
#   0.655548 seconds (25.83 k allocations: 9.807 MiB, 0.24% gc time)
# --------------------------------------
# Full diagonalization
# --------------------------------------
#   0.008630 seconds (23.38 k allocations: 576.766 KiB)
#   0.008525 seconds (23.38 k allocations: 576.766 KiB)
# ite = 1 eps = 0.4525485083630871
# V,Δ at center (Nx/2,Ny/2): -0.7509990048474185 0.16727172573697693
# Δ at corner (1,1): 0.16727172573697538
#   0.008636 seconds (23.38 k allocations: 576.766 KiB)
#   0.008602 seconds (23.38 k allocations: 576.766 KiB)
# ite = 2 eps = 0.243111612266087
# V,Δ at center (Nx/2,Ny/2): -0.7854265731469382 0.24974730781068052
# Δ at corner (1,1): 0.24974730781067847
#   0.008415 seconds (23.38 k allocations: 576.766 KiB)
#   0.008969 seconds (23.38 k allocations: 576.766 KiB)
# ite = 3 eps = 0.08454136146553184
# V,Δ at center (Nx/2,Ny/2): -0.8231907619019254 0.32236382810038816
# Δ at corner (1,1): 0.3223638281003882
#   0.008157 seconds (23.38 k allocations: 576.766 KiB)
#   0.008421 seconds (23.38 k allocations: 576.766 KiB)
# ite = 4 eps = 0.022213656501945532
# V,Δ at center (Nx/2,Ny/2): -0.8485551551125057 0.3704097278064538
# Δ at corner (1,1): 0.3704097278064557
#   0.008242 seconds (23.38 k allocations: 576.766 KiB)
#   0.008089 seconds (23.38 k allocations: 576.766 KiB)
# ite = 5 eps = 0.005233650629665319
# V,Δ at center (Nx/2,Ny/2): -0.8616999316361398 0.39720663966644887
# Δ at corner (1,1): 0.397206639666451
#   0.008365 seconds (23.38 k allocations: 576.766 KiB)
#   0.017096 seconds (23.38 k allocations: 576.766 KiB)
# ite = 6 eps = 0.0011902460823770568
# V,Δ at center (Nx/2,Ny/2): -0.8679885092027415 0.4109102461826654
# Δ at corner (1,1): 0.41091024618266664
#   0.008740 seconds (23.38 k allocations: 576.766 KiB)
#   0.008550 seconds (23.38 k allocations: 576.766 KiB)
# ite = 7 eps = 0.0002674336961584428
# V,Δ at center (Nx/2,Ny/2): -0.8709509598780694 0.4176300258603627
# Δ at corner (1,1): 0.41763002586036213
#   0.008462 seconds (23.38 k allocations: 576.766 KiB)
#   0.008557 seconds (23.38 k allocations: 576.766 KiB)
# ite = 8 eps = 5.981077956605962e-5
# V,Δ at center (Nx/2,Ny/2): -0.8723452978842645 0.4208598691163997
# Δ at corner (1,1): 0.42085986911640133
#   0.008429 seconds (23.38 k allocations: 576.766 KiB)
#   0.008709 seconds (23.38 k allocations: 576.766 KiB)
# ite = 9 eps = 1.335040545545317e-5
# V,Δ at center (Nx/2,Ny/2): -0.8730023055500639 0.42239761560344496
# Δ at corner (1,1): 0.42239761560344796
#   0.008388 seconds (23.38 k allocations: 576.766 KiB)
#   0.008294 seconds (23.38 k allocations: 576.766 KiB)
# ite = 10 eps = 2.9773638000091366e-6
# V,Δ at center (Nx/2,Ny/2): -0.8733121569068066 0.42312646434766976
# Δ at corner (1,1): 0.423126464347672
#   0.008430 seconds (23.38 k allocations: 576.766 KiB)
#   0.008307 seconds (23.38 k allocations: 576.766 KiB)
# ite = 11 eps = 6.637372921524073e-7
# End 0.42347118579035364
#   0.271260 seconds (530.61 k allocations: 12.860 MiB)
# --------------------------------------
# -----------Summary           ---------
# --------------------------------------
# Interaction U: -2.0
# Chemical potential: -0.2
# Imaginary axis methods
# Cutoff: 188.49555921538757 i
# Temperature: 0.05
# RSCG: center V,Δ at (Nx/2,Ny/2): -0.8748758302891471 0.42675679988315274
# Full: center V,Δ at (Nx/2,Ny/2): -0.8748758302891465 0.42675679988315274
# Real axis methods
# Cutoff: 10.0
# Temperature: zero
# Chebyshev with nc=1000: center V,Δ at (Nx/2,Ny/2): -0.874348866203227 0.43042459606470995
# Full: center V,Δ at(Nx/2,Ny/2): -0.8734583577925489 0.42312646434766976
# --------------------------------------
# All done.
